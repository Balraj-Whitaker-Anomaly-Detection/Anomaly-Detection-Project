# %% [markdown]
# # Anomaly Detection Project
# ***

# %% [markdown]
# ## Executive Summary
# #### Overview
#
# Presented with a set of questions regarding Code Up's cohorts' online traffic patterns for their use of class lessons and documentation, we are to explore the cohorts' web logs to discover answers to the questions given to us.  Using a SQL database and a .csv containing web logs and cohort data, we will be analyzing the data to find how the cohorts accessed the class lessons online.
#
# #### Project Goals
# - Explore, visualize, and analyze data to discover answers to the questions given to us.
# - Create an email in response to the request included below containing findings.
# - Create a single Executive Summary-like slide summarizing most important findings
# - Create a Jupyter Notebook outlining work done to answer questions
#
# #### Outline of Process
#
# The plan for this project is to do the following:
# - Acquire cohort schedule info from SQL database and join with cohorts.csv sent to us.
# - Prepare data by dropping columns, renaming columns, handling null values and creating new columns.
# - Explore data by visualizing and analyzing data.
# - Create questions based off questions sent to us and explore data for answers.
# - Come up with conclusions and gather and notate findings.
# - Create email and Google Slide with responses to questions and key findings
#
# #### Conclusion & Key Findings
#
# - 1. Other than the curriculum landing page, the lesson which appears to attract the **most traffic** consistently across cohorts is the **Javascript I lesson**.
#
# - 2. The **Classification module** in the curriculum was **accessed significantly more by Darden** compared to the other cohorts, referring to it over 4000 times compared to 1,000 - 2,000 for Bayes, Easley and Curie only 94 times for Florence.
#
# - 3. Yes, there are students that, even when active, **hardly access the curriculum**.
#     - User ID 278 only accessed the curriculum 3 times while active in the program and was in the Voyageurs cohort for Java between 5-29-2018 and 10-11-2018
#      - User ID 832 only accessed the curriculum 2 times while active in the program and was in the Jupiter cohort for Java between 9/21/2020 and 3/30/2021
#      - User ID 679 only accessed the curriculum 1 time while active in the program and was in the Darden cohort for Data Science between 7/13/2020 - 1/12/2021
#
# - 4. Yes, **899 anomalies were found using Bollinger Bands** indicating the web traffic looked unusual for its web page access. In looking at one more closely, it appears that **four pages were visited at the same time**.  Could be bots?
#
# - 5. Yes, in **June of 2019** the web traffic dips sharply indicating that **the acccess of both curriculums was shut down**.  It looks like in **early 2019 access was also shut down**.
#
# - 6. The **topics that web dev grads are continuing to reference** after graduation are:
#     - javascript-i
#     - spring
#     - html-css
#     - java-i
#     - java-ii
#     - java-iii
#
#     The **topics that data science grads are continuing to reference** after graduation are:
#     - sql/mysql-overview
#     - classification/overview
#     - anomaly-detection/overview
#     - fundamentals/intro-to-data-science
#
# - 7. **Several pages are only accessed once**. It's difficult to tell if its an actual lesson, or a page that was not intended for student use.
#
# - 8. Of note, **735 IP addresses have only accessed the curriculum logs once** and 451 paths have only been accessed once.
#
# #### Next Steps:
#
# - With more time, I would like to continue exploring the anomalies found and look for more patterns using time series anomaly methods and discrete and continuous anomaly methods.

# %% [markdown]
# ***
# ##### For Reference:
# >Project Scenario from Google Assignment
# >
# >Hello,
# >
# >I have some questions for you that I need to be answered before the board meeting Friday afternoon. I need to be >able to speak to the following questions. I also need a single slide that I can incorporate into my existing >presentation (Google Slides) that summarizes the most important points. My questions are listed below; however, if >you discover anything else important that I didn’t think to ask, please include that as well.
# >
# >
# >1. Which lesson appears to attract the most traffic consistently across cohorts (per program)?
# >2. Is there a cohort that referred to a lesson significantly more than other cohorts seemed to gloss over?
# >3. Are there students who, when active, hardly access the curriculum? If so, what information do you have about these students?
# >4. Is there any suspicious activity, such as users/machines/etc accessing the curriculum who shouldn’t be? Does it appear that any web-scraping is happening? Are there any suspicious IP addresses?
# >5. At some point in 2019, the ability for students and alumni to access both curriculums (web dev to ds, ds to web dev) should have been shut off. Do you see any evidence of that happening? Did it happen before?
# >6. What topics are grads continuing to reference after graduation and into their jobs (for each program)?
# >7. Which lessons are least accessed?
# >8. Anything else I should be aware of?
# >
# >
# >Thank you
# >
# ***

# %% [markdown]
# # Acquire

# %% [markdown]
# We were given a .csv file containing cohorts data.  Will read that into a dataframe to explore.

# %%
#Disable warnings
import warnings
warnings.filterwarnings('ignore')

#Import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Scaler import
from sklearn.preprocessing import MinMaxScaler

# DBSCAN import
from sklearn.cluster import DBSCAN

#Import custom libraries
import acquire
import prepare

# %%
df_csv = pd.read_csv('cohorts.csv')

# %%
df_csv.head()
# Out:
#    cohort_id        name  start_date    end_date  program_id
# 0          1      Arches  2014-02-04  2014-04-22           1
# 1          2    Badlands  2014-06-04  2014-08-22           1
# 2          3    Carlsbad  2014-09-04  2014-11-05           1
# 3          4      Denali  2014-10-20  2015-01-18           1
# 4          5  Everglades  2014-11-18  2015-02-24           1

# %%
df_csv.shape
# Out:
# (46, 5)

# %%
df_csv.info
# Out:
# <bound method DataFrame.info of     cohort_id        name  start_date    end_date  program_id
# 0           1      Arches  2014-02-04  2014-04-22           1
# 1           2    Badlands  2014-06-04  2014-08-22           1
# 2           3    Carlsbad  2014-09-04  2014-11-05           1
# 3           4      Denali  2014-10-20  2015-01-18           1
# 4           5  Everglades  2014-11-18  2015-02-24           1
# 5           6    Franklin  2015-02-03  2015-05-26           1
# 6           7     Glacier  2015-06-05  2015-10-06           1
# 7           8     Hampton  2015-09-22  2016-02-06           1
# 8           9      Apollo  2015-03-30  2015-07-29           4
# 9          10      Balboa  2015-11-03  2016-03-11           4
# 10         11         Ike  2016-01-20  2016-05-12           1
# 11         12      Joshua  2016-03-08  2016-06-30           1
# 12         13       Kings  2016-05-23  2016-09-15           1
# 13         14      Lassen  2016-07-18  2016-11-10           1
# 14         15     Mammoth  2016-09-26  2017-02-02           2
# 15         16     Niagara  2016-10-26  2017-03-09           2
# 16         17     Olympic  2017-02-06  2017-05-25           1
# 17         18   Pinnacles  2017-03-27  2017-07-20           2
# 18         19      Quincy  2017-06-05  2017-09-22           1
# 19         20     Redwood  2017-07-31  2017-12-06           2
# 20         21     Sequoia  2017-09-27  2018-02-15           2
# 21         22       Teddy  2018-01-08  2018-05-17           2
# 22         23     Ulysses  2018-03-05  2018-07-19           2
# 23         24   Voyageurs  2018-05-29  2018-10-11           2
# 24         25    Wrangell  2018-07-23  2018-11-29           2
# 25         26      Xanadu  2018-09-17  2019-02-08           2
# 26         27    Yosemite  2018-11-05  2019-04-03           2
# 27         28       Staff  2014-02-04  2014-02-04           2
# 28         29        Zion  2019-01-22  2019-06-04           2
# 29         30         Ada  2019-02-04  2019-06-16           3
# 30         31   Andromeda  2019-03-18  2019-07-30           2
# 31         32  Betelgeuse  2019-05-28  2019-10-08           2
# 32         33       Ceres  2019-07-15  2019-12-11           2
# 33         34       Bayes  2019-08-19  2020-01-30           3
# 34         51      Deimos  2019-09-16  2020-02-27           2
# 35         52      Europa  2019-11-04  2020-04-17           2
# 36         53     Fortuna  2020-01-13  2020-06-23           2
# 37         55       Curie  2020-02-03  2020-07-07           3
# 38         56        Apex  2020-02-24  2020-07-29           2
# 39         57    Ganymede  2020-03-23  2020-08-20           2
# 40         58    Hyperion  2020-05-26  2020-11-10           2
# 41         59      Darden  2020-07-13  2021-01-12           3
# 42         60          Io  2020-07-20  2021-01-21           2
# 43         61        Bash  2020-07-20  2021-01-21           2
# 44         62     Jupiter  2020-09-21  2021-03-30           2
# 45        132     Kalypso  2020-11-02  2021-05-04           2>

# %% [markdown]
# - It looks like we have the Code Up cohorts names, dates started and date ended.

# %% [markdown]
# We will acquire data from the curriculum logs DB using SQL queries and our acquire.py

# %%
df = acquire.get_cohort_log_data()

# %%
df.head()
# Out:
#    id name slack start_date end_date created_at updated_at  deleted_at  \
# 0 NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# 1 NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# 2 NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# 3 NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# 4 NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
#
#    program_id        date      time  \
# 0         NaN  2021-04-21  12:36:54
# 1         NaN  2021-04-21  12:36:59
# 2         NaN  2021-04-21  12:37:31
# 3         NaN  2021-04-21  12:38:25
# 4         NaN  2021-04-21  12:38:43
#
#                                                 path  user_id  cohort_id  \
# 0                                                toc      717        NaN
# 1          javascript-i/introduction/primitive-types      717        NaN
# 2                javascript-i/introduction/operators      717        NaN
# 3                javascript-i/introduction/variables      717        NaN
# 4  javascript-i/introduction/working-with-data-ty...      717        NaN
#
#                ip
# 0  136.50.102.126
# 1  136.50.102.126
# 2  136.50.102.126
# 3  136.50.102.126
# 4  136.50.102.126

# %%
df.shape
# Out:
# (900223, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900223 entries, 0 to 900222
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          847330 non-null  float64
#  1   name        847330 non-null  object
#  2   slack       847330 non-null  object
#  3   start_date  847330 non-null  object
#  4   end_date    847330 non-null  object
#  5   created_at  847330 non-null  object
#  6   updated_at  847330 non-null  object
#  7   deleted_at  0 non-null       float64
#  8   program_id  847330 non-null  float64
#  9   date        900223 non-null  object
#  10  time        900223 non-null  object
#  11  path        900222 non-null  object
#  12  user_id     900223 non-null  int64
#  13  cohort_id   847330 non-null  float64
#  14  ip          900223 non-null  object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 109.9+ MB

# %%
df.tail()
# Out:
#            id    name    slack  start_date    end_date           created_at  \
# 900218  139.0  Oberon  #oberon  2021-04-12  2021-10-01  2021-04-12 18:07:21
# 900219  139.0  Oberon  #oberon  2021-04-12  2021-10-01  2021-04-12 18:07:21
# 900220  139.0  Oberon  #oberon  2021-04-12  2021-10-01  2021-04-12 18:07:21
# 900221  139.0  Oberon  #oberon  2021-04-12  2021-10-01  2021-04-12 18:07:21
# 900222  139.0  Oberon  #oberon  2021-04-12  2021-10-01  2021-04-12 18:07:21
#
#                  updated_at  deleted_at  program_id        date      time  \
# 900218  2021-04-12 18:07:21         NaN         2.0  2021-04-21  12:13:18
# 900219  2021-04-12 18:07:21         NaN         2.0  2021-04-21  12:31:48
# 900220  2021-04-12 18:07:21         NaN         2.0  2021-04-21  12:31:58
# 900221  2021-04-12 18:07:21         NaN         2.0  2021-04-21  12:32:01
# 900222  2021-04-12 18:07:21         NaN         2.0  2021-04-21  13:14:10
#
#                                        path  user_id  cohort_id             ip
# 900218  javascript-i/testing-user-functions      969      139.0  107.77.169.64
# 900219                         javascript-i      969      139.0  107.77.169.64
# 900220    javascript-i/javascript-with-html      969      139.0  107.77.169.64
# 900221  javascript-i/testing-user-functions      969      139.0  107.77.169.64
# 900222                                    /      970      139.0  172.56.14.200

# %% [markdown]
# - Our dataframe returns the data from the curriculum logs for all cohorts at Code Up.

# %% [markdown]
# ## Prepare

# %% [markdown]
# Now that we've acquired our data, let's look for nulls.

# %%
df.isna().sum()
# Out:
# id             52893
# name           52893
# slack          52893
# start_date     52893
# end_date       52893
# created_at     52893
# updated_at     52893
# deleted_at    900223
# program_id     52893
# date               0
# time               0
# path               1
# user_id            0
# cohort_id      52893
# ip                 0
# dtype: int64

# %%
acquire.nulls_by_col(df)
# Out:
#             num_rows_missing  percent_rows_missing
# id                     52893              5.875544
# name                   52893              5.875544
# slack                  52893              5.875544
# start_date             52893              5.875544
# end_date               52893              5.875544
# created_at             52893              5.875544
# updated_at             52893              5.875544
# deleted_at            900223            100.000000
# program_id             52893              5.875544
# date                       0              0.000000
# time                       0              0.000000
# path                       1              0.000111
# user_id                    0              0.000000
# cohort_id              52893              5.875544
# ip                         0              0.000000

# %%
acquire.nulls_by_row(df)
# Out:
#   num_cols_missing percent_cols_missing   index
# 0                1    6.666666666666667  847329
# 1                2   13.333333333333334       1
# 2               10    66.66666666666666   52893

# %%
df[df.name.isna() & df.program_id.isna()]
# Out:
#        id name slack start_date end_date created_at updated_at  deleted_at  \
# 0     NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# 1     NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# 2     NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# 3     NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# 4     NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# ...    ..  ...   ...        ...      ...        ...        ...         ...
# 52888 NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# 52889 NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# 52890 NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# 52891 NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
# 52892 NaN  NaN   NaN        NaN      NaN        NaN        NaN         NaN
#
#        program_id        date      time  \
# 0             NaN  2021-04-21  12:36:54
# 1             NaN  2021-04-21  12:36:59
# 2             NaN  2021-04-21  12:37:31
# 3             NaN  2021-04-21  12:38:25
# 4             NaN  2021-04-21  12:38:43
# ...           ...         ...       ...
# 52888         NaN  2019-08-08  10:19:19
# 52889         NaN  2019-08-08  10:19:20
# 52890         NaN  2019-08-08  15:29:32
# 52891         NaN  2019-08-09  08:01:30
# 52892         NaN  2019-08-09  08:52:34
#
#                                                     path  user_id  cohort_id  \
# 0                                                    toc      717        NaN
# 1              javascript-i/introduction/primitive-types      717        NaN
# 2                    javascript-i/introduction/operators      717        NaN
# 3                    javascript-i/introduction/variables      717        NaN
# 4      javascript-i/introduction/working-with-data-ty...      717        NaN
# ...                                                  ...      ...        ...
# 52888               java-ii/inheritance-and-polymorphism       48        NaN
# 52889            java-ii/interfaces-and-abstract-classes       48        NaN
# 52890                                                  /      362        NaN
# 52891                                                  /      367        NaN
# 52892                6-classification/6.2-decision-trees      351        NaN
#
#                     ip
# 0       136.50.102.126
# 1       136.50.102.126
# 2       136.50.102.126
# 3       136.50.102.126
# 4       136.50.102.126
# ...                ...
# 52888   216.177.189.26
# 52889   216.177.189.26
# 52890   70.123.200.145
# 52891  216.180.182.238
# 52892  173.173.114.111
#
# [52893 rows x 15 columns]

# %% [markdown]
# #### Deciding to drop nulls since they do not have a cohort associated to them and eliminates much of the earlier data during curriculum and cohort establishment making for a cleaner data frame.  Will look into nulls later. Will add code to drop nulls in prepare.py.

# %%
df = prepare.prepare_data()
df.head()
# Out:
#             Unnamed: 0   id    name    slack           start_date  \
# 0  2019-06-01 17:31:28  1.0  Arches  #arches  2014-02-04 00:00:00
# 1  2019-06-01 17:31:35  1.0  Arches  #arches  2014-02-04 00:00:00
# 2  2019-06-01 17:31:40  1.0  Arches  #arches  2014-02-04 00:00:00
# 3  2019-06-01 17:56:01  1.0  Arches  #arches  2014-02-04 00:00:00
# 4  2019-06-01 18:06:35  1.0  Arches  #arches  2014-02-04 00:00:00
#
#               end_date           created_at           updated_at  program_id  \
# 0  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# 1  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# 2  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# 3  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# 4  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
#
#                   date                 time  \
# 0  2019-06-01 00:00:00  2021-10-21 17:31:28
# 1  2019-06-01 00:00:00  2021-10-21 17:31:35
# 2  2019-06-01 00:00:00  2021-10-21 17:31:40
# 3  2019-06-01 00:00:00  2021-10-21 17:56:01
# 4  2019-06-01 00:00:00  2021-10-21 18:06:35
#
#                                 path  user_id  cohort_id             ip  \
# 0                             java-i      402        1.0  71.78.236.131
# 1  java-i/syntax-types-and-variables      402        1.0  71.78.236.131
# 2                           html-css      402        1.0  71.78.236.131
# 3                  html-css/elements      402        1.0  71.78.236.131
# 4                  html-css/elements      402        1.0  71.78.236.131
#
#   program_type
# 0          php
# 1          php
# 2          php
# 3          php
# 4          php

# %%
#Checking to see that nulls were dropped
df.isna().sum()
# Out:
# Unnamed: 0      0
# id              0
# name            0
# slack           0
# start_date      0
# end_date        0
# created_at      0
# updated_at      0
# program_id      0
# date            0
# time            0
# path            0
# user_id         0
# cohort_id       0
# ip              0
# program_type    0
# dtype: int64

# %% [markdown]
# - Nulls have been removed

# %%
#Look at prepped dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 764015 entries, 0 to 764014
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    764015 non-null  object
#  1   id            764015 non-null  float64
#  2   name          764015 non-null  object
#  3   slack         764015 non-null  object
#  4   start_date    764015 non-null  object
#  5   end_date      764015 non-null  object
#  6   created_at    764015 non-null  object
#  7   updated_at    764015 non-null  object
#  8   program_id    764015 non-null  float64
#  9   date          764015 non-null  object
#  10  time          764015 non-null  object
#  11  path          764015 non-null  object
#  12  user_id       764015 non-null  int64
#  13  cohort_id     764015 non-null  float64
#  14  ip            764015 non-null  object
#  15  program_type  764015 non-null  object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 93.3+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'slack', 'start_date', 'end_date',
#        'created_at', 'updated_at', 'program_id', 'date', 'time', 'path',
#        'user_id', 'cohort_id', 'ip', 'program_type'],
#       dtype='object')

# %%
#Look at the different counts per each program ID
df.program_id.value_counts()
# Out:
# 2.0    656931
# 3.0     79612
# 1.0     27469
# 4.0         3
# Name: program_id, dtype: int64

# %%
#Look at the distribution of web logs by program type
df.program_type.value_counts()
# Out:
# java            656931
# data_science     79612
# php              27469
# front_end            3
# Name: program_type, dtype: int64

# %%
df.path.value_counts()
# Out:
# javascript-i              18203
# toc                       17591
# java-iii                  13166
# html-css                  13127
# java-ii                   12177
#                           ...
# mysql//sample-database        1
# cli-07-more-topics            1
# 8.0_Intro_Module              1
# bad-charts                    1
# java-1                        1
# Name: path, Length: 2093, dtype: int64

# %% [markdown]
# - Created a new column with description of program type for easier readability
# - We have 52,893 nulls, and dropped them in our prepare.py
# - Dropped 'deleted_at' column because no entries have a value, all are null, which means no web logs have been deleted
# - Removed log entries for paths ending in image or json files

# %% [markdown]
# ## Explore

# %% [markdown]
# Let's dig into the data and see what we find!

# %%
#Create a pair plot to see visual relationships between numeric variables
sns.pairplot(df)

# %%
#Combine date and time columns into one date-time column to use for indexing
#df = df.set_index(pd.to_datetime(df.date + ' ' + df.time))

# %%
df.time.value_counts().head(20).sort_index().plot.bar(title='Which hours were the most active?')
# Out:
# <AxesSubplot:title={'center':'Which hours were the most active?'}>

# %%
df.index.value_counts().head(20).sort_index().plot.bar(title='Which date/times were the most active?')
# Out:
# <AxesSubplot:title={'center':'Which date/times were the most active?'}>

# %%
df.program_type.value_counts().sort_index().plot.barh(title="Which program types are the most popular?")
# Out:
# <AxesSubplot:title={'center':'Which program types are the most popular?'}>

# %%
fig, ax = plt.subplots(figsize=(12,10))
df.name.value_counts().sort_index().plot.barh(title="Which cohorts are the most active online?")
# Out:
# <AxesSubplot:title={'center':'Which cohorts are the most active online?'}>

# %% [markdown]
# - After Code Up staff, Ceres was the most frequest accessor of the curriculum.

# %%
# Daily counts for number of page views
df.date = pd.to_datetime(df.date)
df = df.set_index(df.date)

pages = df['path'].resample('d').count()
pages.head()
# Out:
# date
# 2018-01-26    489
# 2018-01-27    202
# 2018-01-28    142
# 2018-01-29    715
# 2018-01-30    566
# Freq: D, Name: path, dtype: int64

# %%
#plot pages
pages.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Questions

# %% [markdown]
# ### 1. Which lesson appears to attract the most traffic consistently across cohorts (per program)?</code>

# %%
df.path.value_counts().head(10).plot.barh(
    title='Top 10 Most Commonly Requested Pages');

# %%
def value_counts_and_frequencies(s: pd.Series, dropna=True) -> pd.DataFrame:
    return pd.merge(
        s.value_counts(dropna=False).rename('count'),
        s.value_counts(dropna=False, normalize=True).rename('proba'),
        left_index=True,
        right_index=True,
    )

# %%
#Look at the top lessons accessed
path_df = value_counts_and_frequencies(df.path)
path_df.head(10)
# Out:
#                count     proba
# javascript-i   18203  0.023825
# toc            17591  0.023024
# java-iii       13166  0.017233
# html-css       13127  0.017182
# java-ii        12177  0.015938
# spring         11883  0.015553
# jquery         11041  0.014451
# mysql          10611  0.013888
# java-i         10467  0.013700
# javascript-ii  10294  0.013474

# %%
#Look at the 20 lessons least accessed
path_df.tail(20)
# Out:
#                                                   count     proba
# 9_Appendix_TSAD_Lesson2                               1  0.000001
# content/postwork/dashboard.md                         1  0.000001
# examples/css/..%5c                                    1  0.000001
# content/loops.html                                    1  0.000001
# quizzes                                               1  0.000001
# slides/exceptions                                     1  0.000001
# help                                                  1  0.000001
# cli-02-listing-files                                  1  0.000001
# html-css/introduction:view-page                       1  0.000001
# ada-capsontes.html                                    1  0.000001
# mysql/clauses/limit-order-by                          1  0.000001
# viz.py                                                1  0.000001
# content/appendix/javascript/functions/scope.html      1  0.000001
# strudents                                             1  0.000001
# learn-to-code                                         1  0.000001
# mysql//sample-database                                1  0.000001
# cli-07-more-topics                                    1  0.000001
# 8.0_Intro_Module                                      1  0.000001
# bad-charts                                            1  0.000001
# java-1                                                1  0.000001

# %% [markdown]
# - The javascript - i lesson looks to be the most commonly requested page

# %% [markdown]
# ### 2. Is there a cohort that referred to a lesson significantly more that other cohorts seemed to gloss over?</code>

# %% [markdown]
# - Will group by program type to compare cohorts and then look at the max lessons viewed and how they compared to other cohorts.
# - Will also group paths by module splitting the lessons at the first '/' to categorize into modules instead of individual lessons.

# %%
#Let's take a look at user lesson counts
lesson_counts_by_cohort = df.groupby(['name'])['date','name','path'].nunique()
lesson_counts_by_cohort
# Out:
#             date  name  path
# name
# Andromeda    430     1   334
# Apex         381     1   271
# Apollo         1     1     2
# Arches       272     1   317
# Badlands      11     1    42
# Bash         251     1   273
# Bayes        491     1   489
# Betelgeuse   415     1   310
# Ceres        461     1   288
# Curie        340     1   386
# Darden       275     1   386
# Deimos       476     1   282
# Denali         1     1     3
# Easley       135     1   209
# Europa       360     1   264
# Florence      38     1   141
# Fortuna      351     1   256
# Franklin      11     1    43
# Ganymede     324     1   293
# Glacier       41     1   114
# Hampton      157     1   251
# Hyperion     271     1   267
# Ike           17     1    79
# Joshua        14     1   109
# Jupiter      212     1   284
# Kalypso      169     1   271
# Kings        167     1   291
# Lassen       523     1   432
# Luna         135     1   237
# Mammoth       52     1   212
# Marco         86     1   246
# Neptune       38     1   134
# Niagara      116     1   133
# Oberon        10     1    46
# Olympic      297     1   334
# Pinnacles    212     1   301
# Quincy       109     1   242
# Sequoia      403     1   294
# Staff        804     1  1321
# Teddy        563     1   507
# Ulysses      529     1   374
# Voyageurs    388     1   347
# Wrangell     255     1   406
# Xanadu       433     1   272
# Yosemite     291     1   294
# Zion         438     1   302

# %%
#Let's take a look at user lesson counts by path
lesson_counts_by_path = df.groupby(['path'])['date','name'].nunique()
lesson_counts_by_path.max()
# Out:
# date    1139
# name      40
# dtype: int64

# %%
#Create an initial lesson category to group paths by
df['module_1'] = df.path.str.split('/').str[0]
df['module_2'] = df.path.str.split('/').str[1]
df.head()
# Out:
#                      Unnamed: 0   id    name    slack           start_date  \
# date
# 2019-06-01  2019-06-01 17:31:28  1.0  Arches  #arches  2014-02-04 00:00:00
# 2019-06-01  2019-06-01 17:31:35  1.0  Arches  #arches  2014-02-04 00:00:00
# 2019-06-01  2019-06-01 17:31:40  1.0  Arches  #arches  2014-02-04 00:00:00
# 2019-06-01  2019-06-01 17:56:01  1.0  Arches  #arches  2014-02-04 00:00:00
# 2019-06-01  2019-06-01 18:06:35  1.0  Arches  #arches  2014-02-04 00:00:00
#
#                        end_date           created_at           updated_at  \
# date
# 2019-06-01  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26
# 2019-06-01  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26
# 2019-06-01  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26
# 2019-06-01  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26
# 2019-06-01  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26
#
#             program_id       date                 time  \
# date
# 2019-06-01         1.0 2019-06-01  2021-10-21 17:31:28
# 2019-06-01         1.0 2019-06-01  2021-10-21 17:31:35
# 2019-06-01         1.0 2019-06-01  2021-10-21 17:31:40
# 2019-06-01         1.0 2019-06-01  2021-10-21 17:56:01
# 2019-06-01         1.0 2019-06-01  2021-10-21 18:06:35
#
#                                          path  user_id  cohort_id  \
# date
# 2019-06-01                             java-i      402        1.0
# 2019-06-01  java-i/syntax-types-and-variables      402        1.0
# 2019-06-01                           html-css      402        1.0
# 2019-06-01                  html-css/elements      402        1.0
# 2019-06-01                  html-css/elements      402        1.0
#
#                        ip program_type  module_1                    module_2
# date
# 2019-06-01  71.78.236.131          php    java-i                         NaN
# 2019-06-01  71.78.236.131          php    java-i  syntax-types-and-variables
# 2019-06-01  71.78.236.131          php  html-css                         NaN
# 2019-06-01  71.78.236.131          php  html-css                    elements
# 2019-06-01  71.78.236.131          php  html-css                    elements

# %%
# Let's create a subset of data science students to compare lessons by cohort
ds_cohorts = df[(df['program_type'] == 'data_science')  & (df['name'] != 'staff')]
ds_cohorts
# Out:
#                      Unnamed: 0     id      name      slack  \
# date
# 2021-01-27  2021-01-27 14:03:03   34.0     Bayes          #
# 2021-01-28  2021-01-28 08:17:27   34.0     Bayes          #
# 2021-01-28  2021-01-28 08:17:50   34.0     Bayes          #
# 2021-01-28  2021-01-28 10:11:10   34.0     Bayes          #
# 2021-01-28  2021-01-28 10:37:44   34.0     Bayes          #
# ...                         ...    ...       ...        ...
# 2021-04-08  2021-04-08 13:57:08  137.0  Florence  #florence
# 2021-04-08  2021-04-08 13:59:05  137.0  Florence  #florence
# 2021-04-08  2021-04-08 14:01:22  137.0  Florence  #florence
# 2021-04-08  2021-04-08 14:04:14  137.0  Florence  #florence
# 2021-04-08  2021-04-08 14:05:13  137.0  Florence  #florence
#
#                      start_date             end_date           created_at  \
# date
# 2021-01-27  2019-08-19 00:00:00  2020-01-30 00:00:00  2019-08-20 14:38:55
# 2021-01-28  2019-08-19 00:00:00  2020-01-30 00:00:00  2019-08-20 14:38:55
# 2021-01-28  2019-08-19 00:00:00  2020-01-30 00:00:00  2019-08-20 14:38:55
# 2021-01-28  2019-08-19 00:00:00  2020-01-30 00:00:00  2019-08-20 14:38:55
# 2021-01-28  2019-08-19 00:00:00  2020-01-30 00:00:00  2019-08-20 14:38:55
# ...                         ...                  ...                  ...
# 2021-04-08  2021-03-15 00:00:00  2021-09-03 00:00:00  2021-03-15 18:18:20
# 2021-04-08  2021-03-15 00:00:00  2021-09-03 00:00:00  2021-03-15 18:18:20
# 2021-04-08  2021-03-15 00:00:00  2021-09-03 00:00:00  2021-03-15 18:18:20
# 2021-04-08  2021-03-15 00:00:00  2021-09-03 00:00:00  2021-03-15 18:18:20
# 2021-04-08  2021-03-15 00:00:00  2021-09-03 00:00:00  2021-03-15 18:18:20
#
#                      updated_at  program_id       date                 time  \
# date
# 2021-01-27  2019-08-20 14:38:55         3.0 2021-01-27  2021-10-21 14:03:03
# 2021-01-28  2019-08-20 14:38:55         3.0 2021-01-28  2021-10-21 08:17:27
# 2021-01-28  2019-08-20 14:38:55         3.0 2021-01-28  2021-10-21 08:17:50
# 2021-01-28  2019-08-20 14:38:55         3.0 2021-01-28  2021-10-21 10:11:10
# 2021-01-28  2019-08-20 14:38:55         3.0 2021-01-28  2021-10-21 10:37:44
# ...                         ...         ...        ...                  ...
# 2021-04-08  2021-03-15 18:18:20         3.0 2021-04-08  2021-10-21 13:57:08
# 2021-04-08  2021-03-15 18:18:20         3.0 2021-04-08  2021-10-21 13:59:05
# 2021-04-08  2021-03-15 18:18:20         3.0 2021-04-08  2021-10-21 14:01:22
# 2021-04-08  2021-03-15 18:18:20         3.0 2021-04-08  2021-10-21 14:04:14
# 2021-04-08  2021-03-15 18:18:20         3.0 2021-04-08  2021-10-21 14:05:13
#
#                                              path  user_id  cohort_id  \
# date
# 2021-01-27        python/data-types-and-variables      478       34.0
# 2021-01-28                      appendix/postwork      474       34.0
# 2021-01-28  appendix/interview_questions_students      474       34.0
# 2021-01-28  appendix/interview_questions_students      474       34.0
# 2021-01-28                     clustering/explore      485       34.0
# ...                                           ...      ...        ...
# 2021-04-08              python/control-structures      905      137.0
# 2021-04-08              python/control-structures      949      137.0
# 2021-04-08        python/data-types-and-variables      949      137.0
# 2021-04-08              python/control-structures      912      137.0
# 2021-04-08        python/data-types-and-variables      911      137.0
#
#                         ip  program_type    module_1  \
# date
# 2021-01-27    67.11.138.10  data_science      python
# 2021-01-28  50.206.173.154  data_science    appendix
# 2021-01-28  50.206.173.154  data_science    appendix
# 2021-01-28  50.206.173.154  data_science    appendix
# 2021-01-28  173.174.142.84  data_science  clustering
# ...                    ...           ...         ...
# 2021-04-08    66.69.44.254  data_science      python
# 2021-04-08   136.49.16.164  data_science      python
# 2021-04-08   136.49.16.164  data_science      python
# 2021-04-08   67.11.147.201  data_science      python
# 2021-04-08  54.218.132.133  data_science      python
#
#                                 module_2
# date
# 2021-01-27      data-types-and-variables
# 2021-01-28                      postwork
# 2021-01-28  interview_questions_students
# 2021-01-28  interview_questions_students
# 2021-01-28                       explore
# ...                                  ...
# 2021-04-08            control-structures
# 2021-04-08            control-structures
# 2021-04-08      data-types-and-variables
# 2021-04-08            control-structures
# 2021-04-08      data-types-and-variables
#
# [79612 rows x 18 columns]

# %%
ds_lesson_counts_by_path = ds_cohorts.groupby(['name'])['module_1','path'].nunique()
ds_lesson_counts_by_path
# Out:
#           module_1  path
# name
# Bayes           72   489
# Curie           51   386
# Darden          66   386
# Easley          34   209
# Florence        35   141

# %%
ds_lesson_counts_by_path.plot.barh()
# Out:
# <AxesSubplot:ylabel='name'>

# %% [markdown]
# - It looks like Bayes had the most frequent access to the curriculum of all data science cohorts

# %%
ds_cohorts.module_1.value_counts()
# Out:
# sql                            7505
# classification                 6458
# 3-sql                          6165
# python                         5599
# fundamentals                   5015
#                                ...
# viz.py                            1
# bad-charts                        1
# curie-statistics-assessment       1
# itc%20-%20ml                      1
# tidy-data                         1
# Name: module_1, Length: 135, dtype: int64

# %% [markdown]
# - It looks like the SQL and classification modules are the most popular among all data science cohorts

# %%
# plot data
fig, ax = plt.subplots(figsize=(15,10))
# use unstack()
ds_cohorts.groupby(['name','module_1']).count().unstack().head(10).plot.barh(ax=ax)
ax.legend().set_visible(False)

# %%
ds = ds_cohorts.groupby(['name','module_1']).count().unstack()
ds
# Out:
#          Unnamed: 0                                       \
# module_1  %20https: ,%20https: 1-fundamentals 1-overview
# name
# Bayes           NaN        NaN         1596.0        2.0
# Curie           1.0        1.0         1068.0        NaN
# Darden          NaN        NaN         1174.0        NaN
# Easley          NaN        NaN           62.0        NaN
# Florence        NaN        NaN           64.0        NaN
#
#                                                                            \
# module_1 1.2-data-science-pipeline 1.3-pipeline-demo 10-anomaly-detection
# name
# Bayes                          NaN               NaN                813.0
# Curie                          NaN               NaN                583.0
# Darden                         5.0               4.0                 35.0
# Easley                         NaN               NaN                  NaN
# Florence                       NaN               NaN                  NaN
#
#                                                        ...   module_2  \
# module_1  11-nlp 12-distributed-ml 13-advanced-topics  ... subqueries
# name                                                   ...
# Bayes     1118.0             512.0              604.0  ...        NaN
# Curie      735.0             305.0              404.0  ...        NaN
# Darden      12.0               1.0                3.0  ...        NaN
# Easley       NaN               NaN                NaN  ...        NaN
# Florence     NaN               NaN                NaN  ...        0.0
#
#                                                                          \
# module_1 tidy-data timeseries  toc understand user-defined-functions.md
# name
# Bayes          0.0       78.0  0.0        NaN                       NaN
# Curie          NaN      133.0  NaN        NaN                       NaN
# Darden         NaN      938.0  0.0        NaN                       NaN
# Easley         NaN      435.0  NaN        0.0                       0.0
# Florence       NaN        6.0  NaN        NaN                       NaN
#
#
# module_1 viz.py vocabulary where working-with-time-series-data
# name
# Bayes       0.0        NaN   NaN                           NaN
# Curie       NaN        NaN   NaN                           NaN
# Darden      NaN        NaN   NaN                           0.0
# Easley      NaN        0.0   NaN                           NaN
# Florence    NaN        0.0   0.0                           NaN
#
# [5 rows x 2160 columns]

# %% [markdown]
# - It looks like Darden is accessing a module more than the other cohorts.  Let's take a closer look at each cohort..

# %%
ds_bayes = ds_cohorts[ds_cohorts['name']== 'Bayes']

dsb = ds_bayes.module_1.value_counts()

# %%
dsb.head(20).plot.barh()
plt.title ("Most Frequently Accessed Lessons for Bayes")
# Out:
# Text(0.5, 1.0, 'Most Frequently Accessed Lessons for Bayes')

# %%
ds_curie = ds_cohorts[ds_cohorts['name']== 'Curie']

dsc = ds_curie.module_1.value_counts()
dsc
# Out:
# 3-sql                                    2499
# 4-python                                 2330
# 6-regression                             1957
# 7-classification                         1213
# appendix                                 1161
# 5-stats                                  1157
# 1-fundamentals                           1068
# 11-nlp                                    735
# 8-clustering                              674
# 2-storytelling                            620
# 9-timeseries                              591
# 10-anomaly-detection                      583
# 13-advanced-topics                        404
# sql                                       380
# 12-distributed-ml                         305
# classification                            291
# fundamentals                              219
# python                                    212
# nlp                                       161
# timeseries                                133
# stats                                     114
# regression                                 90
# anomaly-detection                          81
# distributed-ml                             47
# clustering                                 43
# advanced-topics                            34
# storytelling                               21
# curie-python-assessment                     7
# login                                       4
# curie-python-assessemt                      3
# project                                     2
# 3-probability-distributions                 2
# 3-acquire                                   2
# 3-data-types-and-variables                  2
# 3-databases                                 2
# curie-stats-assessment                      2
# 4.5-more-statistical-testing-examples       2
# grades                                      2
# overview                                    1
# 4.2-compare-means                           1
# b-clustering                                1
# search                                      1
# %20https:                                   1
# ,%20https:                                  1
# A-clustering                                1
# java-ii                                     1
# spring                                      1
# stats-assessment                            1
# statistics-assessment                       1
# capstones                                   1
# curie-statistics-assessment                 1
# Name: module_1, dtype: int64

# %%
dsc.head(20).plot.barh()
plt.title ("Most Frequently Accessed Lessons for Curie")
# Out:
# Text(0.5, 1.0, 'Most Frequently Accessed Lessons for Curie')

# %%
ds_darden = ds_cohorts[ds_cohorts['name']== 'Darden']

dsd = ds_darden.module_1.value_counts()
dsd
# Out:
# classification               4031
# sql                          2771
# python                       2572
# stats                        1942
# regression                   1539
#                              ...
# git                             1
# evaluation                      1
# imports                         1
# 12-distributed-ml               1
# 2.1-spreadsheets-overview       1
# Name: module_1, Length: 66, dtype: int64

# %%
dsd.head(20).plot.barh()
plt.title ("Most Frequently Accessed Lessons for Darden")
# Out:
# Text(0.5, 1.0, 'Most Frequently Accessed Lessons for Darden')

# %%
ds_easley = ds_cohorts[ds_cohorts['name']== 'Easley']

dse = ds_easley.module_1.value_counts()
dse
# Out:
# sql                          1871
# classification               1820
# fundamentals                 1507
# python                       1275
# regression                   1140
# stats                         967
# storytelling                  672
# clustering                    645
# timeseries                    435
# appendix                      282
# anomaly-detection             144
# individual-project             80
# 1-fundamentals                 62
# nlp                            34
# advanced-topics                26
# capstones                      22
# distributed-ml                  8
# environment-setup               8
# 6-regression                    4
# user-defined-functions.md       3
# series                          3
# 2-storytelling                  3
# pandas-overview                 2
# explore                         1
# understand                      1
# functions                       1
# refine                          1
# 9-timeseries                    1
# 7-classification                1
# vocabulary                      1
# evaluate                        1
# 3-sql                           1
# introduction-to-python          1
# present                         1
# Name: module_1, dtype: int64

# %%
dse.head(20).plot.barh()
plt.title ("Most Frequently Accessed Lessons for Easley")
# Out:
# Text(0.5, 1.0, 'Most Frequently Accessed Lessons for Easley')

# %%
ds_florence = ds_cohorts[ds_cohorts['name']== 'Florence']

dsf = ds_florence.module_1.value_counts()
dsf
# Out:
# sql                                2277
# fundamentals                       1767
# python                             1349
# appendix                            140
# classification                       94
# 1-fundamentals                       64
# anomaly-detection                    19
# florence-python-assessment.html      16
# storytelling                         16
# regression                           15
# dataframes                           11
# git                                   8
# cli                                   7
# timeseries                            6
# clustering                            5
# stats                                 5
# nlp                                   4
# mysql-introduction                    4
# pandas-overview                       3
# vocabulary                            2
# distributed-ml                        2
# series                                2
# subqueries                            2
# environment-setup                     1
# functions                             1
# advanced-topics                       1
# data-science-pipeline                 1
# basic-statements                      1
# where                                 1
# sql.mysql-overview                    1
# group-by                              1
# capstones                             1
# databases                             1
# case-statements                       1
# joins                                 1
# Name: module_1, dtype: int64

# %%
dsf.head(20).plot.barh()
plt.title ("Most Frequently Accessed Lessons for Florence")
# Out:
# Text(0.5, 1.0, 'Most Frequently Accessed Lessons for Florence')

# %% [markdown]
# - The Classification module in the curriculum was accessed significantly more by Darden compared to the other cohorts.

# %% [markdown]
# ### 3. Are there students who, when active, hardly access the curriculum? If so, what information do you have about these students?</code>

# %% [markdown]
# - I will need to check students' start and end date and see how often they referenced the curriculum

# %%
#Create a new column 'is_active' to check against for entries while student was active in the program
df['is_active'] = np.where(((df['date'] > df['start_date']) & (df['date'] < df['end_date']) & (df['name']!= 'Staff') ), 1, 0)

# %%
df.head()
# Out:
#                      Unnamed: 0   id    name    slack           start_date  \
# date
# 2019-06-01  2019-06-01 17:31:28  1.0  Arches  #arches  2014-02-04 00:00:00
# 2019-06-01  2019-06-01 17:31:35  1.0  Arches  #arches  2014-02-04 00:00:00
# 2019-06-01  2019-06-01 17:31:40  1.0  Arches  #arches  2014-02-04 00:00:00
# 2019-06-01  2019-06-01 17:56:01  1.0  Arches  #arches  2014-02-04 00:00:00
# 2019-06-01  2019-06-01 18:06:35  1.0  Arches  #arches  2014-02-04 00:00:00
#
#                        end_date           created_at           updated_at  \
# date
# 2019-06-01  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26
# 2019-06-01  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26
# 2019-06-01  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26
# 2019-06-01  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26
# 2019-06-01  2014-04-22 00:00:00  2016-06-14 19:52:26  2016-06-14 19:52:26
#
#             program_id       date                 time  \
# date
# 2019-06-01         1.0 2019-06-01  2021-10-21 17:31:28
# 2019-06-01         1.0 2019-06-01  2021-10-21 17:31:35
# 2019-06-01         1.0 2019-06-01  2021-10-21 17:31:40
# 2019-06-01         1.0 2019-06-01  2021-10-21 17:56:01
# 2019-06-01         1.0 2019-06-01  2021-10-21 18:06:35
#
#                                          path  user_id  cohort_id  \
# date
# 2019-06-01                             java-i      402        1.0
# 2019-06-01  java-i/syntax-types-and-variables      402        1.0
# 2019-06-01                           html-css      402        1.0
# 2019-06-01                  html-css/elements      402        1.0
# 2019-06-01                  html-css/elements      402        1.0
#
#                        ip program_type  module_1                    module_2  \
# date
# 2019-06-01  71.78.236.131          php    java-i                         NaN
# 2019-06-01  71.78.236.131          php    java-i  syntax-types-and-variables
# 2019-06-01  71.78.236.131          php  html-css                         NaN
# 2019-06-01  71.78.236.131          php  html-css                    elements
# 2019-06-01  71.78.236.131          php  html-css                    elements
#
#             is_active
# date
# 2019-06-01          0
# 2019-06-01          0
# 2019-06-01          0
# 2019-06-01          0
# 2019-06-01          0

# %% [markdown]
# - Use Conditional Probabilities to find user ids for active students accessing the curriculum the least

# %%
#Let's look at user ids that are active status
status_given_user_id = (
    df.groupby('is_active')
    .user_id.value_counts(normalize=True)
    .rename('proba_status_given_user_id')
    .reset_index()
)
status_given_user_id.head()
# Out:
#    is_active  user_id  proba_status_given_user_id
# 0          0       64                    0.085191
# 1          0       11                    0.077927
# 2          0       53                    0.069942
# 3          0      314                    0.041934
# 4          0        1                    0.033765

# %%
#Look at the 10 user ids for active students to who least accessed the curriculum
status_given_user_id.tail(10)
# Out:
#       is_active  user_id  proba_status_given_user_id
# 1438          1      963                    0.000025
# 1439          1      968                    0.000025
# 1440          1      889                    0.000024
# 1441          1      572                    0.000019
# 1442          1      388                    0.000012
# 1443          1      812                    0.000012
# 1444          1      956                    0.000007
# 1445          1      278                    0.000005
# 1446          1      832                    0.000003
# 1447          1      679                    0.000002

# %%
#Look at the 10 user ids for non-active students to who least accessed the curriculum
status_given_user_id[status_given_user_id['is_active']== 0].tail(10)
# Out:
#      is_active  user_id  proba_status_given_user_id
# 715          0      906                    0.000006
# 716          0      910                    0.000006
# 717          0      922                    0.000006
# 718          0      924                    0.000006
# 719          0      925                    0.000006
# 720          0      932                    0.000006
# 721          0      933                    0.000006
# 722          0      934                    0.000006
# 723          0      960                    0.000006
# 724          0      961                    0.000006

# %%
#Let's find out more about the 3 least active user ids for active student not accessing the curriculum too frequently
df[(df.user_id == 278) | (df.user_id == 832)|(df.user_id == 679)]
# Out:
#                      Unnamed: 0    id       name       slack  \
# date
# 2018-09-27  2018-09-27 14:47:37  24.0  Voyageurs  #voyageurs
# 2018-09-27  2018-09-27 14:58:48  24.0  Voyageurs  #voyageurs
# 2018-09-27  2018-09-27 14:59:07  24.0  Voyageurs  #voyageurs
# 2019-02-09  2019-02-09 15:10:03  24.0  Voyageurs  #voyageurs
# 2019-02-09  2019-02-09 15:10:17  24.0  Voyageurs  #voyageurs
# ...                         ...   ...        ...         ...
# 2020-07-13  2020-07-13 14:39:36  59.0     Darden     #darden
# 2020-07-13  2020-07-13 15:49:31  59.0     Darden     #darden
# 2020-07-14  2020-07-14 08:05:15  59.0     Darden     #darden
# 2020-12-07  2020-12-07 14:22:38  62.0    Jupiter    #jupiter
# 2020-12-07  2020-12-07 14:22:39  62.0    Jupiter    #jupiter
#
#                      start_date             end_date           created_at  \
# date
# 2018-09-27  2018-05-29 00:00:00  2018-10-11 00:00:00  2018-05-25 22:25:57
# 2018-09-27  2018-05-29 00:00:00  2018-10-11 00:00:00  2018-05-25 22:25:57
# 2018-09-27  2018-05-29 00:00:00  2018-10-11 00:00:00  2018-05-25 22:25:57
# 2019-02-09  2018-05-29 00:00:00  2018-10-11 00:00:00  2018-05-25 22:25:57
# 2019-02-09  2018-05-29 00:00:00  2018-10-11 00:00:00  2018-05-25 22:25:57
# ...                         ...                  ...                  ...
# 2020-07-13  2020-07-13 00:00:00  2021-01-12 00:00:00  2020-07-13 18:32:19
# 2020-07-13  2020-07-13 00:00:00  2021-01-12 00:00:00  2020-07-13 18:32:19
# 2020-07-14  2020-07-13 00:00:00  2021-01-12 00:00:00  2020-07-13 18:32:19
# 2020-12-07  2020-09-21 00:00:00  2021-03-30 00:00:00  2020-09-21 18:06:27
# 2020-12-07  2020-09-21 00:00:00  2021-03-30 00:00:00  2020-09-21 18:06:27
#
#                      updated_at  program_id       date                 time  \
# date
# 2018-09-27  2018-05-25 22:25:57         2.0 2018-09-27  2021-10-21 14:47:37
# 2018-09-27  2018-05-25 22:25:57         2.0 2018-09-27  2021-10-21 14:58:48
# 2018-09-27  2018-05-25 22:25:57         2.0 2018-09-27  2021-10-21 14:59:07
# 2019-02-09  2018-05-25 22:25:57         2.0 2019-02-09  2021-10-21 15:10:03
# 2019-02-09  2018-05-25 22:25:57         2.0 2019-02-09  2021-10-21 15:10:17
# ...                         ...         ...        ...                  ...
# 2020-07-13  2020-07-13 18:32:19         3.0 2020-07-13  2021-10-21 14:39:36
# 2020-07-13  2020-07-13 18:32:19         3.0 2020-07-13  2021-10-21 15:49:31
# 2020-07-14  2020-07-13 18:32:19         3.0 2020-07-14  2021-10-21 08:05:15
# 2020-12-07  2020-09-21 18:06:27         2.0 2020-12-07  2021-10-21 14:22:38
# 2020-12-07  2020-09-21 18:06:27         2.0 2020-12-07  2021-10-21 14:22:39
#
#                                                 path  user_id  cohort_id  \
# date
# 2018-09-27                            java-ii/arrays      278       24.0
# 2018-09-27                            java-ii/arrays      278       24.0
# 2018-09-27                       java-ii/collections      278       24.0
# 2019-02-09                                     mysql      278       24.0
# 2019-02-09                        mysql/introduction      278       24.0
# ...                                              ...      ...        ...
# 2020-07-13  1-fundamentals/1.1-intro-to-data-science      679       59.0
# 2020-07-13  1-fundamentals/1.1-intro-to-data-science      679       59.0
# 2020-07-14  1-fundamentals/1.1-intro-to-data-science      679       59.0
# 2020-12-07                              javascript-i      832       62.0
# 2020-12-07                                  html-css      832       62.0
#
#                        ip  program_type        module_1  \
# date
# 2018-09-27   107.77.217.9          java         java-ii
# 2018-09-27   107.77.217.9          java         java-ii
# 2018-09-27   107.77.217.9          java         java-ii
# 2019-02-09   67.11.175.66          java           mysql
# 2019-02-09   67.11.175.66          java           mysql
# ...                   ...           ...             ...
# 2020-07-13  24.28.146.155  data_science  1-fundamentals
# 2020-07-13  24.28.146.155  data_science  1-fundamentals
# 2020-07-14  24.28.146.155  data_science  1-fundamentals
# 2020-12-07   69.154.52.98          java    javascript-i
# 2020-12-07   69.154.52.98          java        html-css
#
#                              module_2  is_active
# date
# 2018-09-27                     arrays          1
# 2018-09-27                     arrays          1
# 2018-09-27                collections          1
# 2019-02-09                        NaN          0
# 2019-02-09               introduction          0
# ...                               ...        ...
# 2020-07-13  1.1-intro-to-data-science          0
# 2020-07-13  1.1-intro-to-data-science          0
# 2020-07-14  1.1-intro-to-data-science          1
# 2020-12-07                        NaN          1
# 2020-12-07                        NaN          1
#
# [69 rows x 19 columns]

# %%
active_students_prob = status_given_user_id[status_given_user_id['is_active']== 1]
active_students_prob.tail(5).plot.barh(x = 'user_id', y='proba_status_given_user_id',figsize=(5, 5))
plt.xlabel("Probability of Use")
plt.ylabel("User ID")
plt.title ('Lowest Active User IDs While Enrolled')
# Out:
# Text(0.5, 1.0, 'Lowest Active User IDs While Enrolled')

# %%
df[(df.user_id == 278)&(df.is_active == 1)].shape,df[(df.user_id == 832) & (df.is_active == 1)].shape,df[(df.user_id == 679) & (df.is_active == 1)].shape
# Out:
# ((3, 19), (2, 19), (1, 19))

# %% [markdown]
# - User ID 278 only accessed the curriculum 3 times while active in the program and was in the Voyageurs cohort for Java between 5-29-2018 and 10-11-2018
# - User ID 832 only accessed the curriculum 2 times while active in the program and was in the Jupiter cohort for Java between 9/21/2020 and 3/30/2021
# - User ID 679 only accessed the curriculum 1 time while active in the program and was in the Darden cohort for Data Science between 7/13/2020 - 1/12/2021

# %% [markdown]
# #### Bollinger Bands

# %%
# set the window span
span = 30

# compute midband
midband = pages.ewm(span = 30).mean()
midband.head()
# Out:
# date
# 2018-01-26    489.000000
# 2018-01-27    340.716667
# 2018-01-28    270.014439
# 2018-01-29    392.624177
# 2018-01-30    432.071374
# Freq: D, Name: path, dtype: float64

# %%
# compute exponential moving stdev
std = pages.ewm(span = 30).std()
std.head()
# Out:
# date
# 2018-01-26           NaN
# 2018-01-27    202.939646
# 2018-01-28    183.036434
# 2018-01-29    272.730596
# 2018-01-30    245.978869
# Freq: D, Name: path, dtype: float64

# %%
# compute upper and lower bands
ub = midband + std * 3
lb = midband - std * 3
ub.head()
# Out:
# date
# 2018-01-26            NaN
# 2018-01-27     949.535605
# 2018-01-28     819.123741
# 2018-01-29    1210.815965
# 2018-01-30    1170.007980
# Freq: D, Name: path, dtype: float64

# %%
# concat pages, midband, lb and ub to create a new df 'my_df'

my_df = pd.concat([pages, midband, ub, lb], axis =1)

my_df.columns = ['pages', 'midband', 'ub', 'lb']
my_df.head()
# Out:
#             pages     midband           ub          lb
# date
# 2018-01-26    489  489.000000          NaN         NaN
# 2018-01-27    202  340.716667   949.535605 -268.102272
# 2018-01-28    142  270.014439   819.123741 -279.094863
# 2018-01-29    715  392.624177  1210.815965 -425.567611
# 2018-01-30    566  432.071374  1170.007980 -305.865231

# %%
#Plot the bands
fig, ax = plt.subplots(figsize=(12,8))

ax.plot(my_df.index, my_df.pages, label='Number of Pages')

ax.plot(my_df.index, my_df.midband, label = '30-day EMA/midband')
ax.plot(my_df.index, my_df.ub, label = 'Upper Band')
ax.plot(my_df.index, my_df.lb, label = 'Lower Band')

ax.legend(loc='best')
ax.set_ylabel('Number of pages')

plt.show()

# %%
#Compute pct_b
my_df['pct_b'] = (my_df['pages'] - my_df['lb'])/ (my_df['ub'] - my_df['lb'])
my_df.head()
# Out:
#             pages     midband           ub          lb     pct_b
# date
# 2018-01-26    489  489.000000          NaN         NaN       NaN
# 2018-01-27    202  340.716667   949.535605 -268.102272  0.386077
# 2018-01-28    142  270.014439   819.123741 -279.094863  0.383434
# 2018-01-29    715  392.624177  1210.815965 -425.567611  0.697005
# 2018-01-30    566  432.071374  1170.007980 -305.865231  0.590745

# %%
my_df[my_df.pct_b > 1]
# Out:
# Empty DataFrame
# Columns: [pages, midband, ub, lb, pct_b]
# Index: []

# %%
def compute_pct_b(pages, span, weight, user):
    midband = pages.ewm(span=span).mean()
    stdev = pages.ewm(span=span).std()
    ub = midband + stdev * weight
    lb = midband - stdev * weight
    bb = pd.concat([ub, lb], axis=1)
    my_df = pd.concat([pages, midband, bb], axis=1)
    my_df.columns = ['pages', 'midband', 'ub', 'lb']
    my_df['pct_b'] = (my_df['pages'] - my_df['lb'])/(my_df['ub'] - my_df['lb'])
    my_df['user_id'] = user
    return my_df

# %%
def plt_bands(my_df, user):
    fig, ax = plt.subplots(figsize=(12,8))
    ax.plot(my_df.index, my_df.pages, label='Number of Pages, User: '+str(user))
    ax.plot(my_df.index, my_df.midband, label = 'EMA/midband')
    ax.plot(my_df.index, my_df.ub, label = 'Upper Band')
    ax.plot(my_df.index, my_df.lb, label = 'Lower Band')
    ax.legend(loc='best')
    ax.set_ylabel('Number of Pages')
    plt.show()

# %%
def find_anomalies(df, pages, user, span, weight):
    my_df = compute_pct_b(pages, span, weight, user)
    #plt_bands(my_df, user)
    return my_df[my_df.pct_b > 1 ]

# %%
span = 30
weight = 2.35

anomalies = pd.DataFrame()
for u in list(df.user_id.unique()):
    user_df = find_anomalies(df, pages, u, span, weight)
    anomalies = pd.concat([anomalies, user_df], axis=0)

# %%
anomalies
# Out:
#             pages     midband           ub          lb     pct_b  user_id
# date
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      402
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      313
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      211
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157       11
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157       64
# ...           ...         ...          ...         ...       ...      ...
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      964
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      970
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      963
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      961
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      956
#
# [899 rows x 6 columns]

# %%
# look at value counts for pages in anomalies
anomalies.pages.value_counts(sort = False)
# Out:
# 1116    899
# Name: pages, dtype: int64

# %%
anomalies[anomalies.pages == 1116]
# Out:
#             pages     midband           ub          lb     pct_b  user_id
# date
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      402
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      313
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      211
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157       11
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157       64
# ...           ...         ...          ...         ...       ...      ...
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      964
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      970
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      963
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      961
# 2018-02-27   1116  443.671687  1096.219146 -208.875771  1.015157      956
#
# [899 rows x 6 columns]

# %% [markdown]
# - 899 anomalies found.  Looking at one of the anomalies found below.

# %%
df[df.user_id == 956]
# Out:
#                      Unnamed: 0     id    name    slack           start_date  \
# date
# 2021-04-15  2021-04-15 14:54:10  139.0  Oberon  #oberon  2021-04-12 00:00:00
# 2021-04-15  2021-04-15 14:55:05  139.0  Oberon  #oberon  2021-04-12 00:00:00
# 2021-04-15  2021-04-15 14:56:04  139.0  Oberon  #oberon  2021-04-12 00:00:00
# 2021-04-15  2021-04-15 15:32:22  139.0  Oberon  #oberon  2021-04-12 00:00:00
#
#                        end_date           created_at           updated_at  \
# date
# 2021-04-15  2021-10-01 00:00:00  2021-04-12 18:07:21  2021-04-12 18:07:21
# 2021-04-15  2021-10-01 00:00:00  2021-04-12 18:07:21  2021-04-12 18:07:21
# 2021-04-15  2021-10-01 00:00:00  2021-04-12 18:07:21  2021-04-12 18:07:21
# 2021-04-15  2021-10-01 00:00:00  2021-04-12 18:07:21  2021-04-12 18:07:21
#
#             program_id       date                 time  \
# date
# 2021-04-15         2.0 2021-04-15  2021-10-21 14:54:10
# 2021-04-15         2.0 2021-04-15  2021-10-21 14:55:05
# 2021-04-15         2.0 2021-04-15  2021-10-21 14:56:04
# 2021-04-15         2.0 2021-04-15  2021-10-21 15:32:22
#
#                                                  path  user_id  cohort_id  \
# date
# 2021-04-15                                        toc      956      139.0
# 2021-04-15        javascript-i/introduction/operators      956      139.0
# 2021-04-15  javascript-i/introduction/primitive-types      956      139.0
# 2021-04-15        javascript-i/introduction/operators      956      139.0
#
#                          ip program_type      module_1      module_2  \
# date
# 2021-04-15  162.200.114.251         java           toc           NaN
# 2021-04-15  162.200.114.251         java  javascript-i  introduction
# 2021-04-15  162.200.114.251         java  javascript-i  introduction
# 2021-04-15  162.200.114.251         java  javascript-i  introduction
#
#             is_active
# date
# 2021-04-15          1
# 2021-04-15          1
# 2021-04-15          1
# 2021-04-15          1

# %% [markdown]
# - It appears that four pages were accessed at the same time.  Could it be a bot? Suspicious.

# %% [markdown]
# ### 7. Which lessons are least accessed?</code>

# %%
#Looking only at students for lessons accessed
students = df[df['name']!= 'Staff']

# %%
fig, ax = plt.subplots(figsize=(9,7))
students.path.value_counts().tail(30).plot.barh(
    title='30 Least Commonly Requested Pages',
)
# Out:
# <AxesSubplot:title={'center':'30 Least Commonly Requested Pages'}>

# %%
students.path.value_counts().tail(50)
# Out:
# 02_listing_files                          1
# ui/typography                             1
# nlp                                       1
# html-css/css-ii/boostrap-grid-system      1
# quiz118                                   1
# decision-trees                            1
# students/743/notes                        1
# prework/cli/03-filepaths                  1
# further-reading                           1
# 10.04.01_FeatureExtraction_FreqBased      1
# 2-storytelling/1-overview/www.qlik.com    1
# java-1                                    1
# students/468/notes                        1
# statistics-assessment                     1
# java-iii/jdbc/poop                        1
# A-clustering/project                      1
# 7-classification/svm                      1
# content/html-css/elements-i/lists.html    1
# appendix/interview-questions-students     1
# ,%20https://github.com/RaulCPena          1
# students/units/75/sub_units/268           1
# 7.03_Explore                              1
# 8.0_Intro_Module                          1
# javascript-i/primitive-types              1
# classification/explore-old                1
# examples/css/..%5c                        1
# arash-arghavan                            1
# jacascript-i/introdection                 1
# slides/exceptions_and_errorhandlings      1
# 10.04.04_TextClassification               1
# 10._NLP                                   1
# viz.py                                    1
# 6.01.02_Acquirecsv                        1
# 131                                       1
# javascript-ii/promisesdfghjkjhgfs         1
# 4.6.0_DS_Libraries_Overview               1
# content/examples/php/arithmetic.php       1
# slides/threads                            1
# jupiter                                   1
# 13.01.02.03_Sketch                        1
# 13.01.01_Understand                       1
# 7.00_Intro                                1
# appendix/capstone                         1
# wp-admin                                  1
# ajax-api-request.html                     1
# 11.04_Modeling.md                         1
# javascript-i/html-css                     1
# examples/html/welcome                     1
# 4_Objects                                 1
# home                                      1
# Name: path, dtype: int64

# %% [markdown]
# - Several pages are only accessed once.  It's difficult to tell if its an actual lesson, or a page that was not intended for student use.

# %% [markdown]
# #### 8. Anything else I should be aware of?</code>

# %%
# get the counts of ips in the dataset

ip_df = pd.DataFrame(df.ip.value_counts(dropna=False)).reset_index().\
                rename(columns={'index': 'ip', 'ip': 'ip_count'})

# %%
ip_df.head(20)
# Out:
#                  ip  ip_count
# 0      97.105.19.58    248829
# 1      97.105.19.61     57563
# 2   192.171.117.210      8460
# 3     71.150.217.33      6194
# 4    12.106.208.194      4028
# 5       67.11.50.23      3942
# 6     70.121.183.95      3742
# 7    76.185.145.231      3435
# 8     172.124.67.93      3377
# 9      67.10.174.56      3066
# 10    24.243.67.104      3020
# 11   70.112.179.142      2865
# 12    72.190.174.52      2605
# 13    99.76.233.212      2548
# 14    104.10.49.137      2537
# 15    66.196.21.182      2500
# 16    99.151.201.25      2390
# 17   72.179.164.139      2307
# 18    216.63.31.195      2287
# 19    136.50.32.151      2266

# %%
ip_df.tail(20)
# Out:
#                    ip  ip_count
# 4927     172.56.7.199         1
# 4928     172.58.99.25         1
# 4929  199.116.115.143         1
# 4930   173.127.107.19         1
# 4931    72.190.178.21         1
# 4932    172.58.99.146         1
# 4933    172.58.99.179         1
# 4934    174.207.7.252         1
# 4935   189.146.46.149         1
# 4936   174.246.135.44         1
# 4937      196.52.2.59         1
# 4938    174.207.1.195         1
# 4939      71.40.4.250         1
# 4940      172.56.7.87         1
# 4941     68.203.222.3         1
# 4942     72.181.57.49         1
# 4943   172.58.102.191         1
# 4944       64.9.239.9         1
# 4945  159.192.201.107         1
# 4946   99.203.155.142         1

# %%
ip_df[ip_df['ip_count'] == 1].nunique()
# Out:
# ip          738
# ip_count      1
# dtype: int64

# %% [markdown]
# - 738 IP addresses have only accessed the curriculum once

# %%
# get the counts of paths in the dataset

paths_df = pd.DataFrame(df.path.value_counts(dropna=False)).reset_index().\
                rename(columns={'index': 'path', 'path': 'path_count'})

# %%
paths_df[paths_df['path_count'] == 1].nunique()
# Out:
# path          451
# path_count      1
# dtype: int64

# %%
paths_df[paths_df['path_count'] == 1].head(50)
# Out:
#                                                    path  path_count
# 1642                                      capstone/team           1
# 1643                                        capstone/50           1
# 1644                                  4.2-compare-means           1
# 1645                                            loguout           1
# 1646                appendix/extra-exercises/javascript           1
# 1647  html-css/css-i/positioning/specimen/MaterialIc...           1
# 1648                                       objects/math           1
# 1649               11-distributed-ml/6.1-prepare-part-1           1
# 1650                                             itc-ml           1
# 1651                                   7_kmeans_by_hand           1
# 1652                                              where           1
# 1653                             mysql//extra-exercises           1
# 1654                                           javascri           1
# 1655                                           user/913           1
# 1656            content/php_iii/alternative-syntax.html           1
# 1657                          fundamentals/repositories           1
# 1658                                      elements/html           1
# 1659                              classification/knn.md           1
# 1660                                        student/202           1
# 1661                       appendix/www.opensecrets.org           1
# 1662                                        annotations           1
# 1663                                     mysql/java-iii           1
# 1664  javascript-i/introduction/working-with-data-ty...           1
# 1665                                              joins           1
# 1666                  appendix/open_data/www.census.gov           1
# 1667                                     cheatsheet.tex           1
# 1668                html-css/grid/css-grid-fundamentals           1
# 1669                              6.04.01_Preprocessing           1
# 1670                                               ajax           1
# 1671                                        10.00_Intro           1
# 1672            javascript-i/bom-and-dom/bom/google.com           1
# 1673                                Exploration_Lecture           1
# 1674  content/appendix/javascript/functions/controll...           1
# 1675                            appendix/intellij-intro           1
# 1676                          java-iii/mvc/java-beans/'           1
# 1677                                               html           1
# 1678                             further-reading/spring           1
# 1679  appendix/professional-development/post-intervi...           1
# 1680  javascript-i/bom-and-dom/bom/http%22://www.goo...           1
# 1681          appendix/capstone-workbook/sw-planning.md           1
# 1682                                              teams           1
# 1683             appendix/further-reading/java/intellij           1
# 1684                                             data-1           1
# 1685                 9.4_Detecting_TimeSeries_Anomalies           1
# 1686                             11.02_TransformData.md           1
# 1687                          2.1-spreadsheets-overview           1
# 1688                      Appendix_LeastAngleRegression           1
# 1689           content/appendix/control-structures.html           1
# 1690                           appendix/testing-code.md           1
# 1691                                   javascript-i/dom           1

# %% [markdown]
# - 451 paths have only been accessed once.
